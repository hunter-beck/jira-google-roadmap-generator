# %% [markdown]
# # Working Section

# %%
# Connect / authenticate to Jira
# Retrieve a list of the Jira Tickets on the Roadmap Kanban board

# Connect / authenticate to Google Slides
# Create new placeholder slides for each quarter (where the roadmaps will be populated)

# Iterate through the list of Jira tickets
    # Select the slide to place the ticket on based on the "Product - X" component
    # Select the location on the slide based on the "Status" (e.g., Q1)
    # Create the request body for the initiative and add to growing list

# Write back all of the slide updates in one request to Google Slides

# %% [markdown]
# ## General Purpose Stuff

# %%
from dataclasses import dataclass
import uuid
import json
from dataclasses import dataclass
from datetime import datetime
from jira import JIRA
from getpass import getpass

# %% [markdown]
# ## Google Slides

# %% [markdown]
# ### Authenticate

# %%
from google_auth_oauthlib.flow import InstalledAppFlow, Flow
from googleapiclient.discovery import build


def google_slides_connect():
    '''Authenticate to Google Slides and generate a service to be leveraged when updating/populating slides

    Returns: 
        (googleapiclient.discovery.Resource)
    '''
    
    flow = InstalledAppFlow.from_client_secrets_file(
        'google-credentials.json',
        scopes=['https://www.googleapis.com/auth/presentations'])
    
    credentials = flow.run_local_server()
    
    return build('slides', 'v1', credentials=credentials)

# %%
slides_service = google_slides_connect()
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=1076520620839-3cadpb9secdetc938k51obvoc2tl79sc.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpresentations&state=gdvT0kJ8EbChyZhvaUFQJWA54wQF5t&access_type=offline

# %% [markdown]
# ### Update Slides

# %%
def updateSlides(service, **kwargs):
    '''General function for pushing updates to a specific slide deck'''
    return service.presentations().batchUpdate(**kwargs).execute()

# %% [markdown]
# ### Create Slide

# %%
def gen_header_slide_req(title):
    '''Creates a request body for a new slide

    Args: 
        title (Str): the title of the slide

    Returns: 
        (List(dict)): request body to generate roadmap item
        (str): Google Slides id of the object created
    '''

    titleId = str(uuid.uuid4())
    slideId = str(uuid.uuid4())

    request_body = [
        {
            'createSlide': {
                'objectId':slideId,
                'slideLayoutReference': {
                    'predefinedLayout': 'SECTION_HEADER'
                },
                'placeholderIdMappings': [
                    {
                        'objectId': titleId,
                        'layoutPlaceholder': {'type': 'TITLE', 'index': 0}
                    }
                ]
            }
        },
        {'insertText': {'objectId': titleId, 'text': title}},
    ]
    
    return request_body, slideId

# %%
def gen_roadmap_slide_req(
    title,
    roadmap_slide_config
):
    '''Creates a request body for a new slide

    Args: 
        title (Str): the title of the slide
        roadmap_slide_config (dict): configuration for the roadmap slides
        ...
        
    Returns: 
        (List(dict)): request body to generate roadmap item
        (str): Google Slides id of the object created
    '''

    left_header_config = roadmap_slide_config['left_header'] 
    left_main_config = roadmap_slide_config['left_main'] 
    timeline_arrow_config = roadmap_slide_config['timeline_arrow'] 
    quarter_marker_config = roadmap_slide_config['quarter_marker'] 
    quarters_config = roadmap_slide_config['quarters'] 
    roadmap_box_config = roadmap_slide_config['roadmap_box']
    columns_config = roadmap_slide_config['columns']
    
    title_id = str(uuid.uuid4())
    slide_id = str(uuid.uuid4())    
    left_header_element_id = str(uuid.uuid4())
    left_main_element_id = str(uuid.uuid4())

    left_main_locx=left_header_config["locx"]
    
    # timeline arrow
    timeline_arrow_start_locx = left_header_config["locx"] + left_header_config["width"]
    timeline_arrow_start_locy = left_header_config["locy"] + left_header_config["height"]/2
    timeline_arrow_element_id = str(uuid.uuid4())
    
    
    slide_req = [{
        'createSlide': {
            'objectId':slide_id,
            'slideLayoutReference': {
                'predefinedLayout': 'TITLE_AND_TWO_COLUMNS'
            },
            'placeholderIdMappings': [
                {
                    'objectId': title_id,
                    'layoutPlaceholder': {'type': 'TITLE', 'index': 0}
                }
            ]
        }
    }]

    title_req = [{'insertText': {'objectId': title_id, 'text': title}}]
    
    left_main_req = [{
            "createShape": {
                "objectId": left_main_element_id,
                "shapeType": left_main_config["shape_type"],
                "elementProperties": {
                    "pageObjectId": slide_id,
                    "size": {
                        "height": {"magnitude": left_main_config["height"], "unit": "PT"}, 
                        "width": {"magnitude": left_main_config["width"], "unit": "PT"}
                    },
                    "transform": {
                        "scaleX": 1,
                        "scaleY": 1,
                        "translateX": left_main_locx,
                        "translateY": left_main_config["locy"],
                        "unit": "PT",
                    }
                }
            }
        },
        {
            "updateShapeProperties" : {
                "fields" : "contentAlignment, \
                    outline.outlineFill.solidFill.alpha, \
                    shapeBackgroundFill.solidFill.color.themeColor",
                "objectId": left_main_element_id,
                "shapeProperties" : {
                    "contentAlignment": "TOP",
                    "outline": {"outlineFill": {"solidFill":{"alpha":0}}},
                    "shapeBackgroundFill":{"solidFill": {"color": {"themeColor":left_main_config["color"]}}}
                }
            }
        },
        {
            "insertText": {
                "objectId": left_main_element_id,
                "insertionIndex": 0,
                "text": f"\n\n\n{left_main_config['text']}"
            }
        },
        {
            "updateTextStyle" : {
                "fields": "fontFamily, fontSize.magnitude, fontSize.unit",
                "objectId": left_main_element_id,
                "style" : {
                    "fontFamily": "Manrope",
                    "fontSize": {"magnitude": left_main_config["font_size"], "unit":"PT"}
                },
            }
        },
        {
            "updateParagraphStyle" : {
                "fields": "alignment",
                "objectId": left_main_element_id,
                "style" : {
                    "alignment": "START",
                },
            }
        }]
    
    left_header_req = [{
            "createShape": {
                "objectId": left_header_element_id,
                "shapeType": left_header_config["shape_type"],
                "elementProperties": {
                    "pageObjectId": slide_id,
                    "size": {
                        "height": {"magnitude": left_header_config["height"], "unit": "PT"}, 
                        "width": {"magnitude": left_header_config["width"], "unit": "PT"}
                    },
                    "transform": {
                        "scaleX": 1,
                        "scaleY": 1,
                        "translateX": left_header_config["locx"],
                        "translateY": left_header_config["locy"],
                        "unit": "PT",
                    }
                }
            }
        },
        {
            "updateShapeProperties" : {
                "fields" : "contentAlignment, \
                    outline.outlineFill.solidFill.alpha, \
                    shapeBackgroundFill.solidFill.color.themeColor",
                "objectId": left_header_element_id,
                "shapeProperties" : {
                    "contentAlignment": "TOP",
                    "outline": {"outlineFill": {"solidFill":{"alpha":0}}},
                    "shapeBackgroundFill":{"solidFill": {"color": {"themeColor":left_header_config["color"]}}}
                }
            }
        },
        {
            "insertText": {
                "objectId": left_header_element_id,
                "insertionIndex": 0,
                "text": title
            }
        },
        {
            "updateTextStyle" : {
                "fields": "bold, fontFamily, fontSize.magnitude, fontSize.unit, \
                    foregroundColor.opaqueColor.themeColor",
                "objectId": left_header_element_id,
                "style" : {
                    "bold":True,
                    "fontFamily": "Manrope",
                    "fontSize": {"magnitude": left_header_config["font_size"], "unit":"PT"},
                    "foregroundColor": {"opaqueColor": {"themeColor":"LIGHT1"}}
                },
            }
        },
        {
            "updateParagraphStyle" : {
                "fields": "alignment",
                "objectId": left_header_element_id,
                "style" : {
                    "alignment": "CENTER",
                },
            }
        }]

    timeline_arrow_req = [{
            "createLine": {
                "objectId": timeline_arrow_element_id,
                "lineCategory": 'STRAIGHT',
                "elementProperties": {
                    "pageObjectId": slide_id,
                    "size": {
                        "height": {"magnitude": 1, "unit": "PT"}, 
                        "width": {"magnitude": timeline_arrow_config["width"], "unit": "PT"}
                    },
                    "transform": {
                        "scaleX": 1,
                        "scaleY": 1,
                        "translateX": timeline_arrow_start_locx,
                        "translateY": timeline_arrow_start_locy,
                        "unit": "PT",
                    }
                }
            }
        },
        {
            "updateLineProperties" : {
                "fields" : "endArrow, lineFill.solidFill.color.themeColor, weight",
                "objectId": timeline_arrow_element_id,
                "lineProperties" : {
                    "endArrow": "FILL_ARROW",
                    "lineFill":{"solidFill": {"color": {"themeColor":timeline_arrow_config["color"]}}},
                    "weight": {"magnitude": timeline_arrow_config["weight"], "unit": "PT"}
                }
            }
        }]

    quarter_marker_reqs = []

    quarter_width = (timeline_arrow_config["width"] - roadmap_box_config['x_padding']*2) / len(columns_config)
    quarter_locx = timeline_arrow_start_locx + roadmap_box_config['x_padding']

    text_box_width = 200
    
    for col_num, column in enumerate(columns_config):
        
        quarter_marker_element_id = str(uuid.uuid4())
        quarter_textbox_element_id = str(uuid.uuid4())
    
        quarter_marker_reqs += [
            {
                "createShape": {
                    "objectId": quarter_marker_element_id,
                    "shapeType": quarter_marker_config["shape_type"],
                    "elementProperties": {
                        "pageObjectId": slide_id,
                        "size": {
                            "height": {"magnitude": quarter_marker_config["height"], "unit": "PT"}, 
                            "width": {"magnitude": quarter_marker_config["width"], "unit": "PT"}
                        },
                        "transform": {
                            "scaleX": 1,
                            "scaleY": 1,
                            "translateX": quarter_locx + quarter_width/2 - quarter_marker_config['width']/2 + (quarter_width * col_num),
                            "translateY": timeline_arrow_start_locy - quarter_marker_config["height"]/2,
                            "unit": "PT",
                        }
                    }
                }
            },
            {
                "updateShapeProperties" : {
                    "fields" : "outline.outlineFill.solidFill.alpha, \
                        shapeBackgroundFill.solidFill.color.themeColor",
                    "objectId": quarter_marker_element_id,
                    "shapeProperties" : {
                        "outline": {"outlineFill": {"solidFill":{"alpha":0}}},
                        "shapeBackgroundFill":{"solidFill": {"color": {"themeColor":quarter_marker_config["color"]}}}
                    }
                }
            },
            {
                "createShape": {
                    "objectId": quarter_textbox_element_id,
                    "shapeType": "RECTANGLE",
                    "elementProperties": {
                        "pageObjectId": slide_id,
                        "size": {
                            "height": {"magnitude": quarter_marker_config["height"], "unit": "PT"}, 
                            "width": {"magnitude": text_box_width, "unit": "PT"}
                        },
                        "transform": {
                            "scaleX": 1,
                            "scaleY": 1,
                            "translateX": quarter_locx + quarter_width/2 - text_box_width/2 + (quarter_width * col_num),
                            "translateY": timeline_arrow_start_locy - quarter_marker_config["height"]*1.75,
                            "unit": "PT",
                        }
                    }
                }
            },
            {
                "updateShapeProperties" : {
                    "fields" : "outline.outlineFill.solidFill.alpha, \
                        shapeBackgroundFill.solidFill.alpha",
                    "objectId": quarter_textbox_element_id,
                    "shapeProperties" : {
                        "outline": {"outlineFill": {"solidFill":{"alpha":0}}},
                        "shapeBackgroundFill":{"solidFill":{"alpha":0}}
                    }
                }
            },
            {
                "insertText": {
                    "objectId": quarter_textbox_element_id,
                    "insertionIndex": 0,
                    "text": column['label']
                }
            },
            {
                "updateTextStyle" : {
                    "fields": "bold, fontFamily, fontSize.magnitude, foregroundColor.opaqueColor.themeColor",
                    "objectId": quarter_textbox_element_id,
                    "style" : {
                        "bold": True,
                        "fontFamily": quarter_marker_config['font'],
                        "fontSize": {"magnitude": quarter_marker_config["font_size"], "unit":"PT"},
                        "foregroundColor": {"opaqueColor": {"themeColor":quarter_marker_config['font_color']}}
                    }
                }
            }                
        ]
    
    request_body = slide_req + title_req + left_main_req + left_header_req + timeline_arrow_req + quarter_marker_reqs
    
    return request_body, slide_id

# %%
new_slide_req, slide_id = gen_slide_req("My Awesome Slide", slide_type='roadmap')

res = updateSlides(
    service = slides_service,
    presentationId = '1XDRX_Bq39GTT8_6r2oorklhkw-MuIpn-VqFUSHn_Fdo',
    body = {'requests': new_slide_req}
)

# %% [markdown]
# ### Roadmap Slide Item

# %%
def gen_roadmap_item_req(page_id, width, locx, locy, tagline, description, link, roadmap_box_config):
    '''Creates the necessary request body for generating a roadmap item in Google Slides

    Args: 
        page_id (str): id of the Google Slide page
        width (int): pixel width of roadmap box
        locx (int): location on x-axis
        loxy (int): location on y-axis
        tagline (str): short tagline for the roadmap item
        description (str): 1 - 2 sentences describing the roadmap intiative
        link (str): URL to the jira roadmap item
        roadmap_box_config (dict): configuration of the roadmap boxes

    Returns: 
        (List(dict)): request body to generate roadmap item
        (str): Google Slides id of the object created
    '''
    
    # Properties for all roadmap item boxes
    SHAPE_TYPE='ROUND_RECTANGLE'
    
    ptHeight = {"magnitude": roadmap_box_config["height"], "unit": "PT"}
    ptWidth = {"magnitude": width, "unit": "PT"}

    element_id = str(uuid.uuid4())
    
    request_body = [
        {
            "createShape": {
                "objectId": element_id,
                "shapeType": roadmap_box_config["shape_type"],
                "elementProperties": {
                    "pageObjectId": page_id,
                    "size": {"height": ptHeight, "width": ptWidth},
                    "transform": {
                        "scaleX": 1,
                        "scaleY": 1,
                        "translateX": locx,
                        "translateY": locy,
                        "unit": "PT",
                    }
                }
            }
        },
        {
            "updateShapeProperties" : {
                "fields" : "contentAlignment, \
                    outline.outlineFill.solidFill.color.themeColor, \
                    link.url, \
                    shapeBackgroundFill.solidFill.color.themeColor",
                "objectId": element_id,
                "shapeProperties" : {
                    "contentAlignment": "TOP",
                    "outline": {"outlineFill": {"solidFill": {"color": {"themeColor":roadmap_box_config["outline_color"]}}}},
                    "link": {"url": link},
                    "shapeBackgroundFill":{"solidFill": {"color": {"themeColor":roadmap_box_config["fill_color"]}}}
                }
            }
        },
        {
            "insertText": {
                "objectId": element_id,
                "insertionIndex": 0,
                "text": tagline + '\n' + description,
            }
        },
        {
            "updateTextStyle" : {
                "fields": "bold, fontFamily, fontSize.magnitude, fontSize.unit",
                "objectId": element_id,
                "style" : {
                    "fontFamily": "Manrope",
                    "fontSize": {"magnitude": roadmap_box_config["font_size"], "unit":"PT"}
                },
            }
        },
        {
            "updateParagraphStyle" : {
                "fields": "alignment",
                "objectId": element_id,
                "style" : {
                    "alignment": "START",
                },
            }
        },
        {
            "updateTextStyle" : {
                "fields": "bold",
                "objectId": element_id,
                "style" : {
                    "bold": True,
                },
                "textRange": {"endIndex": len(tagline), "startIndex": 0, "type": "FIXED_RANGE"}
            }
        }
    ]

    return request_body, element_id

# %%
new_shape_req, shape_id = gen_roadmap_item_req(
    page_id=slide_id,
    tagline='Roadmap Initiative 1',
    description='Some sort of description representing the initiative. A bit longer than the tagline.',
    locx=10,
    locy=100,
    link='https://www.google.com'
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 new_shape_req, shape_id = gen_roadmap_item_req(
#       2     page_id=slide_id,
#       3     tagline='Roadmap Initiative 1',
#       4     description='Some sort of description representing the initiative. A bit longer than the tagline.',
#       5     locx=10,
#       6     locy=100,
#       7     link='https://www.google.com'
#       8 )
#
# TypeError: gen_roadmap_item_req() missing 3 required positional arguments: 'height', 'width', and 'font_size'

# %%
res = updateSlides(
    service = slides_service,
    presentationId = '1XDRX_Bq39GTT8_6r2oorklhkw-MuIpn-VqFUSHn_Fdo',
    body = {'requests': new_shape_req}
)

# %% [markdown]
# ## Jira

# %% [markdown]
# ### Connect / Authenticate

# %%
from jira import JIRA
from getpass import getpass

jira_cloud = JIRA(basic_auth=("hunter.beck@cognite.com", getpass('Jira API Key:')), options={'server': 'https://cognitedata.atlassian.net/'})
# Out:
# Jira API Key: ········

# %% [markdown]
# ### Get Roadmap Jira Issues

# %%
@dataclass
class JiraRoadmapIssue:
    summary:str
    description:str
    jira_id:str
    product_categories:list
    quarter:int
    jira_link:str

def get_roadmap_issues(jira_service, jql_filter, product_category_mode, product_category_prefix):
    '''Retrieves all of the Roadmap Initiatives in Jira Cloud

    Args: 
        jira_service (JIRA): authenticated service used for interacting with jira
        jql_filter (str): JQL compliant string to filter the specific issues
        product_category_mode (str): 'components' or 'labels' 
    '''
    
    roadmap_issue_ids = jira_service.search_issues(
        jql_str=jql_filter,
        maxResults=None
    )

    if roadmap_issue_ids:
        
        roadmap_issues = []
        
        for issue_id in roadmap_issue_ids: 

            issue = jira_service.issue(id=issue_id)

            if product_category_mode == 'components':

                issue_categories = [comp.name for comp in issue.fields.components]
            
            elif product_category_mode == 'labels':
                
                issue_categories = issue.fields.labels

            else:
                raise Exception(f"product_category_mode: '{product_category_mode}' is not valid. Choose from either 'components' or 'labels'")

            filtered_categories = []

            for category in issue_categories:

                if category.startswith(product_category_prefix):

                    filtered_categories.append(category[len(product_category_prefix):])
            
            roadmap_issues.append(JiraRoadmapIssue(
                summary=issue.fields.summary,
                description=issue.fields.description,
                jira_id=issue_id.id,
                product_categories=filtered_categories,
                quarter=int(issue.fields.status.name[1:]),
                jira_link=issue.permalink()
            ))
            
        return roadmap_issues

    else: 

        raise Exception("No jira issues were found with the provided JQL Filter")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 @dataclass
#       2 class JiraRoadmapIssue:
#       3     summary:str
#       4     description:str
#
# NameError: name 'dataclass' is not defined

# %%
from lib import get_roadmap_issues

# %%
jira_roadmap_issues = get_roadmap_issues(
    jira_service=jira_client, 
    jira_project='CDFNEW',
    issue_type='Roadmap Initiative',
    product_category_mode = 'components',
    product_category_prefix = 'Product - ',
    include_beta=True,
    beta_attribute_name='customfield_10933'
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 jira_roadmap_issues = get_roadmap_issues(
#       2     jira_service=jira_client,
#       3     jira_project='CDFNEW',
#       4     issue_type='Roadmap Initiative',
#       5     product_category_mode = 'components',
#       6     product_category_prefix = 'Product - ',
#       7     include_beta=True,
#       8     beta_attribute_name='customfield_10933'
#       9 )
#
# File ~/Repos/jira-slide-generator/lib.py:100, in get_roadmap_issues(jira_service, jira_project, issue_type, product_category_mode, product_category_prefix, include_beta, beta_attribute_name)
#      96     issue.fields.description = ''
#      98 if include_beta:
# --> 100     if getattr(issue.fields, beta_attribute_name).value == "Beta":
#     102         beta_flag = True
#     104     elif getattr(issue.fields, beta_attribute_name).value == "Beta":
#
# AttributeError: 'NoneType' object has no attribute 'value'

# %%
jira_roadmap_issues[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 jira_roadmap_issues[0]
#
# NameError: name 'jira_roadmap_issues' is not defined

# %%
roadmap_issue_ids = jira_client.search_issues(
    jql_str='project = CDFNEW and issuetype = "Roadmap Initiative" and status in ("Q1", "Q2", "Q3", "Q4") ORDER BY Rank ASC',
    maxResults=None
)

# %%
issue = jira_client.issue(id=roadmap_issue_ids[4])

# %%
issue.fields.summary
# Out:
# 'Leverage Generative AI co-pilot\n'

# %%
getattr(issue.fields, "customfield_10933")

# %%
issue.fields.summary
# Out:
# 'AI generated apps/dashboards using Streamlit'

# %%
issue.fields.assignee
# Out:
# <JIRA User: displayName='Lars Moastuen', accountId='5ce26e623e6fd40fe82cb171'>

# %%
issue.fields.customfield_10933
# Out:
# <JIRA CustomFieldOption: value='Beta', id='11961'>

# %%
for att in dir(issue.fields):

    print(att, getattr(issue.fields, att))
# Out:
# __class__ <class 'jira.resources.PropertyHolder'>
# __delattr__ <method-wrapper '__delattr__' of PropertyHolder object at 0x108ff29a0>
# __dict__ {'customfield_10870': None, 'customfield_10750': None, 'resolution': None, 'customfield_10871': None, 'customfield_10630': None, 'customfield_10872': None, 'customfield_10752': None, 'customfield_10631': None, 'customfield_10510': None, 'customfield_10500': None, 'customfield_10742': None, 'customfield_10863': None, 'customfield_10864': None, 'customfield_10501': None, 'customfield_10743': None, 'customfield_10502': None, 'customfield_10623': None, 'customfield_10744': None, 'customfield_10865': None, 'customfield_10503': None, 'customfield_10745': None, 'customfield_10624': None, 'customfield_10625': None, 'customfield_10504': None, 'customfield_10746': None, 'customfield_10747': None, 'customfield_10626': None, 'customfield_10505': None, 'customfield_10506': None, 'customfield_10748': None, 'customfield_10627': None, 'customfield_10869': None, 'customfield_10749': None, 'customfield_10628': None, 'customfield_10507': None, 'customfield_10629': None, 'customfield_10508': None, 'customfield_10509': None, 'lastViewed': '2024-03-22T14:12:43.242+0100', 'customfield_10860': None, 'customfield_10740': None, 'customfield_10861': None, 'customfield_10741': None, 'customfield_10862': None, 'customfield_10852': None, 'customfield_10973': None, 'customfield_10854': None, 'customfield_10855': None, 'customfield_10856': None, 'customfield_10735': None, 'aggregatetimeoriginalestimate': None, 'customfield_10857': None, 'customfield_10858': None, 'customfield_10859': None, 'issuelinks': [], 'assignee': <JIRA User: displayName='Lars Moastuen', accountId='5ce26e623e6fd40fe82cb171'>, 'customfield_10970': None, 'customfield_10971': None, 'customfield_10851': None, 'customfield_10972': None, 'customfield_10964': None, 'customfield_10965': None, 'customfield_10966': None, 'customfield_10967': None, 'customfield_10968': None, 'customfield_10969': None, 'subtasks': [], 'customfield_10959': None, 'votes': <JIRA Votes: votes=0>, 'worklog': <jira.resources.PropertyHolder object at 0x108ff26a0>, 'issuetype': <JIRA IssueType: name='Roadmap Initiative', id='11001'>, 'customfield_10943': None, 'customfield_10701': None, 'customfield_10707': None, 'customfield_10708': None, 'customfield_10933': <JIRA CustomFieldOption: value='Beta', id='11961'>, 'customfield_10934': <JIRA CustomFieldOption: value='General Availability', id='11964'>, 'timetracking': <JIRA TimeTracking at 4445908080>, 'customfield_10920': None, 'customfield_10921': None, 'customfield_10922': None, 'customfield_10923': None, 'customfield_10924': None, 'customfield_10925': None, 'customfield_10926': None, 'customfield_10927': None, 'customfield_10928': None, 'customfield_10929': None, 'environment': None, 'customfield_10910': None, 'customfield_10911': None, 'duedate': None, 'customfield_10917': None, 'customfield_10918': None, 'customfield_10919': None, 'customfield_10591': None, 'customfield_10350': None, 'customfield_10592': None, 'customfield_10351': None, 'customfield_10230': None, 'customfield_10231': None, 'customfield_10352': None, 'customfield_10232': None, 'customfield_10353': None, 'customfield_10474': None, 'customfield_10354': None, 'customfield_10234': None, 'customfield_10235': None, 'customfield_10226': None, 'customfield_10348': None, 'customfield_10227': None, 'customfield_10349': None, 'customfield_10228': None, 'customfield_10229': None, 'customfield_10580': None, 'customfield_10581': None, 'customfield_10582': None, 'customfield_10583': None, 'customfield_10465': None, 'customfield_10335': None, 'customfield_10577': None, 'customfield_10214': None, 'customfield_10578': None, 'customfield_10336': None, 'customfield_10579': None, 'customfield_10337': None, 'customfield_10338': None, 'customfield_10339': None, 'timeestimate': None, 'status': <JIRA Status: name='Q2', id='11932'>, 'customfield_10570': None, 'customfield_10571': None, 'customfield_10572': None, 'customfield_10694': None, 'customfield_10210': None, 'customfield_10573': None, 'customfield_10211': None, 'cu ...
# __dir__ <built-in method __dir__ of PropertyHolder object at 0x108ff29a0>
# __doc__ An object for storing named attributes.
# __eq__ <method-wrapper '__eq__' of PropertyHolder object at 0x108ff29a0>
# __format__ <built-in method __format__ of PropertyHolder object at 0x108ff29a0>
# __ge__ <method-wrapper '__ge__' of PropertyHolder object at 0x108ff29a0>
# __getattribute__ <method-wrapper '__getattribute__' of PropertyHolder object at 0x108ff29a0>
# __gt__ <method-wrapper '__gt__' of PropertyHolder object at 0x108ff29a0>
# __hash__ <method-wrapper '__hash__' of PropertyHolder object at 0x108ff29a0>
# __init__ <method-wrapper '__init__' of PropertyHolder object at 0x108ff29a0>
# __init_subclass__ <built-in method __init_subclass__ of type object at 0x1343d8d50>
# __le__ <method-wrapper '__le__' of PropertyHolder object at 0x108ff29a0>
# __lt__ <method-wrapper '__lt__' of PropertyHolder object at 0x108ff29a0>
# __module__ jira.resources
# __ne__ <method-wrapper '__ne__' of PropertyHolder object at 0x108ff29a0>
# __new__ <built-in method __new__ of type object at 0x1015166c8>
# __reduce__ <built-in method __reduce__ of PropertyHolder object at 0x108ff29a0>
# __reduce_ex__ <built-in method __reduce_ex__ of PropertyHolder object at 0x108ff29a0>
# __repr__ <method-wrapper '__repr__' of PropertyHolder object at 0x108ff29a0>
# __setattr__ <method-wrapper '__setattr__' of PropertyHolder object at 0x108ff29a0>
# __sizeof__ <built-in method __sizeof__ of PropertyHolder object at 0x108ff29a0>
# __str__ <method-wrapper '__str__' of PropertyHolder object at 0x108ff29a0>
# __subclasshook__ <built-in method __subclasshook__ of type object at 0x1343d8d50>
# __weakref__ None
# aggregateprogress <jira.resources.PropertyHolder object at 0x108ff2f10>
# aggregatetimeestimate None
# aggregatetimeoriginalestimate None
# aggregatetimespent None
# assignee Lars Moastuen
# attachment []
# comment <JIRA UnknownResource at 4445907216>
# components [<JIRA Component: name='Product - Streamlit', id='11523'>]
# created 2023-08-08T14:38:58.633+0200
# creator Terje Loken
# customfield_10000 {}
# customfield_10001 None
# customfield_10002 None
# customfield_10003 None
# customfield_10004 None
# customfield_10005 None
# customfield_10006 None
# customfield_10007 None
# customfield_10008 None
# customfield_10009 None
# customfield_10010 None
# customfield_10014 None
# customfield_10015 None
# customfield_10016 None
# customfield_10017 None
# customfield_10018 <jira.resources.PropertyHolder object at 0x108ff2ee0>
# customfield_10019 2023-08-24T09:01:28.112+0200
# customfield_10020 None
# customfield_10021 None
# customfield_10022 0|i0rhtb:
# customfield_10023 []
# customfield_10027 None
# customfield_10030 None
# customfield_10034 None
# customfield_10035 None
# customfield_10038 None
# customfield_10039 None
# customfield_10040 None
# customfield_10041 None
# customfield_10042 None
# customfield_10043 None
# customfield_10044 None
# customfield_10045 None
# customfield_10046 None
# customfield_10047 None
# customfield_10048 None
# customfield_10049 None
# customfield_10050 None
# customfield_10051 None
# customfield_10052 None
# customfield_10053 None
# customfield_10054 None
# customfield_10056 None
# customfield_10061 None
# customfield_10062 None
# customfield_10064 None
# customfield_10067 None
# customfield_10074 None
# customfield_10075 None
# customfield_10076 None
# customfield_10082 None
# customfield_10083 None
# customfield_10156 None
# customfield_10157 None
# customfield_10173 None
# customfield_10180 None
# customfield_10197 None
# customfield_10210 None
# customfield_10211 None
# customfield_10212 None
# customfield_10214 None
# customfield_10226 None
# customfield_10227 None
# customfield_10228 None
# customfield_10229 None
# customfield_10230 None
# customfield_10231 None
# customfield_10232 None
# customfield_10234 None
# customfield_10235 None
# customfield_10236 None
# customfield_10238
# customfield_10239 0.0
# customfield_10241 None
# customfield_10242 None
# customfield_10243 None
# customfield_10250 None
# customfield_10251 None
# customfield_10252 None
# customfield_10253 None
# customfield_10254 None
# customfield_10255 None
# customfield_10256 None
# customfield_10257 None
# customfield_10258 None
# customfield_10259 None
# customfield_10260 None
# customfield_10261 None
# customfield_10262 None
# customfield_10263 None
# customfield_10264 None
# customfield_10265 None
# customfield_10266 None
# customfield_10267 None
# customfield_10268 None
# customfield_10269 None
# customfield_10270 None
# customfield_10271 None
# customfield_10272 None
# customfield_10273 None
# customfield_10274 None
# customfield_10275 None
# customfield_10276 None
# customfield_10277 None
# customfield_10278 None
# customfield_10279 None
# customfield_10280 None
# customfield_10281 None
# customfield_10282 None
# customfield_10284 None
# customfield_10285 None
# customfield_10286 None
# customfield_10287 None
# customfield_10293 None
# customfield_10294 None
# customfield_10295 None
# customfield_10299 None
# customfield_10300 None
# customfield_10301 None
# customfield_10302 None
# customfield_10319 None
# customfield_10320 None
# customfield_10321 None
# customfield_10322 None
# customfield_10323 None
# customfield_10324 None
# customfield_10325 None
# customfield_10326 None
# customfield_10335 None
# customfield_10336 None
# customfield_10337 None
# customfield_10338 None
# customfield_10339 None
# customfield_10348 None
# customfield_10349 None
# customfield_10350 None
# customfield_10351 None
# customfield_10352 None
# customfield_10353 None
# customfield_10354 None
# customfield_10361 None
# customfield_10362 None
# customfield_10372 None
# customfield_10373 None
# customfield_10374 None
# customfield_10375 None
# customfield_10376 None
# customfield_10377 None
# customfield_10378 None
# customfield_10379 None
# customfield_10380 None
# customfield_10381 None
# customfield_10382 None
# customfield_10384 None
# customfield_10391 None
# customfield_10392 None
# customfield_10393 None
# customfield_10394 None
# customfield_10396 None
# customfield_10397 None
# customfield_10398 None
# customfield_10399 None
# customfield_10400 None
# customfield_10401 None
# customfield_10402 None
# customfield_10412 None
# customfield_10419 None
# customfield_10420 None
# customfield_10421 None
# customfield_10422 None
# customfield_10423 None
# customfield_10424 None
# customfield_10425 None
# customfield_10426 None
# customfield_10427 None
# customfield_10428 None
# customfield_10429 None
# customfield_10430 []
# customfield_10447 None
# customfield_10448 None
# customfield_10453 None
# customfield_10465 None
# customfield_10474 None
# customfield_10490 None
# customfield_10491 None
# customfield_10492 None
# customfield_10493 None
# customfield_10494 None
# customfield_10495 None
# customfield_10496 None
# customfield_10497 None
# customfield_10498 None
# customfield_10500 None
# customfield_10501 None
# customfield_10502 None
# customfield_10503 None
# customfield_10504 None
# customfield_10505 None
# customfield_10506 None
# customfield_10507 None
# customfield_10508 None
# customfield_10509 None
# customfield_10510 None
# customfield_10514 None
# customfield_10522 None
# customfield_10523 None
# customfield_10524 None
# customfield_10528 None
# customfield_10529 None
# customfield_10530 None
# customfield_10531 None
# customfield_10534 None
# customfield_10535 None
# customfield_10536 None
# customfield_10537 None
# customfield_10551 None
# customfield_10553 None
# customfield_10554 None
# customfield_10555 None
# customfield_10556 None
# customfield_10557 None
# customfield_10558 None
# customfield_10560 None
# customfield_10561 None
# customfield_10562 None
# customfield_10563 None
# customfield_10564 None
# customfield_10565 None
# customfield_10566 None
# customfield_10567 None
# customfield_10568 None
# customfield_10569 None
# customfield_10570 None
# customfield_10571 None
# customfield_10572 None
# customfield_10573 None
# customfield_10574 None
# customfield_10575 None
# customfield_10576 None
# customfield_10577 None
# customfield_10578 None
# customfield_10579 None
# customfield_10580 None
# customfield_10581 None
# customfield_10582 None
# customfield_10583 None
# customfield_10591 None
# customfield_10592 None
# customfield_10623 None
# customfield_10624 None
# customfield_10625 None
# customfield_10626 None
# customfield_10627 None
# customfield_10628 None
# customfield_10629 None
# customfield_10630 None
# customfield_10631 None
# customfield_10641 None
# customfield_10642 None
# customfield_10659 None
# customfield_10663 None
# customfield_10676 None
# customfield_10677 None
# customfield_10678 None
# customfield_10679 None
# customfield_10694 None
# customfield_10701 None
# customfield_10707 None
# customfield_10708 None
# customfield_10735 None
# customfield_10740 None
# customfield_10741 None
# customfield_10742 None
# customfield_10743 None
# customfield_10744 None
# customfield_10745 None
# customfield_10746 None
# customfield_10747 None
# customfield_10748 None
# customfield_10749 None
# customfield_10750 None
# customfield_10752 None
# customfield_10770 None
# customfield_10771 None
# customfield_10775 None
# customfield_10776 None
# customfield_10777 None
# customfield_10778 None
# customfield_10783 None
# customfield_10793 None
# customfield_10794 None
# customfield_10795 None
# customfield_10796 Global
# customfield_10851 None
# customfield_10852 None
# customfield_10854 None
# customfield_10855 None
# customfield_10856 None
# customfield_10857 None
# customfield_10858 None
# customfield_10859 None
# customfield_10860 None
# customfield_10861 None
# customfield_10862 None
# customfield_10863 None
# customfield_10864 None
# customfield_10865 None
# customfield_10869 None
# customfield_10870 None
# customfield_10871 None
# customfield_10872 None
# customfield_10874 None
# customfield_10875 None
# customfield_10879 None
# customfield_10880 None
# customfield_10881 None
# customfield_10882 None
# customfield_10883 None
# customfield_10884 None
# customfield_10886 None
# customfield_10887 None
# customfield_10888 None
# customfield_10905 None
# customfield_10906 None
# customfield_10910 None
# customfield_10911 None
# customfield_10917 None
# customfield_10918 None
# customfield_10919 None
# customfield_10920 None
# customfield_10921 None
# customfield_10922 None
# customfield_10923 None
# customfield_10924 None
# customfield_10925 None
# customfield_10926 None
# customfield_10927 None
# customfield_10928 None
# customfield_10929 None
# customfield_10933 Beta
# customfield_10934 General Availability
# customfield_10943 None
# customfield_10959 None
# customfield_10964 None
# customfield_10965 None
# customfield_10966 None
# customfield_10967 None
# customfield_10968 None
# customfield_10969 None
# customfield_10970 None
# customfield_10971 None
# customfield_10972 None
# customfield_10973 None
# customfield_11009 None
# customfield_11010 None
# customfield_11011 None
# customfield_11012 None
# customfield_11013 None
# customfield_11014 None
# customfield_11016 None
# customfield_11017 None
# customfield_11034 []
# description Low-code client built applications in Python using Streamlit from Fusion
# duedate None
# environment None
# fixVersions []
# issuelinks []
# issuerestriction <jira.resources.PropertyHolder object at 0x108ff2700>
# issuetype Roadmap Initiative
# labels ['roadmap-ai', 'roadmap-userexperience']
# lastViewed 2024-03-22T14:12:43.242+0100
# priority None
# progress <jira.resources.PropertyHolder object at 0x108ff2fd0>
# project CDFNEW
# reporter Terje Loken
# resolution None
# resolutiondate None
# security None
# status Q2
# statuscategorychangedate 2023-12-14T11:42:52.562+0100
# subtasks []
# summary AI generated apps/dashboards using Streamlit
# timeestimate None
# timeoriginalestimate None
# timespent None
# timetracking <JIRA TimeTracking at 4445908080>
# updated 2024-03-22T14:12:45.287+0100
# versions []
# votes 0
# watches <JIRA Watchers at 4445908800>
# worklog <jira.resources.PropertyHolder object at 0x108ff26a0>
# workratio -1

# %% [markdown]
# ## Combining Everything

# %% [markdown]
# ### Using Components or Labels to Generate Sections

# %%
def get_unique_product_groups(roadmap_issues):

    categories = []
    
    for issue in roadmap_issues:

        categories += issue.product_categories

    return list(set(categories))

@dataclass
class RoadmapSlide:
    title:str
    google_slide_id:str
    product_category:str

def generate_roadmap_slides(presentation_id, slides_service, product_categories, roadmap_slide_config):
    '''Creates the section headers and placeholder roadmap slides to populate with roadmap items

    Args:
        presentation_id (str): google id of presentation to add slides to
        slides_service (): google authenticated service to use when creating slides
        product_categories (list(str)): list of unique product categories
        roadmap_slide_config (dict): all of the properties required to create the roadmap slides

    Returns:
        (list(RoadmapSlides)): slides generated 
    '''
    
    slide_reqs = []
    slides = []
    
    for category in product_categories:
    
        header_slide_req, header_slide_id = gen_header_slide_req(title=category)
    
        slide_reqs += header_slide_req    
    
        roadmap_slide_req, roadmap_slide_id = gen_roadmap_slide_req(
            title = category, 
            roadmap_slide_config = roadmap_slide_config
        )
    
        slides.append(RoadmapSlide(
            title=category,
            google_slide_id=roadmap_slide_id,
            product_category=category
        ))
        
        slide_reqs += roadmap_slide_req

    res = updateSlides(
        service = slides_service,
        presentationId = presentation_id,
        body = {'requests': slide_reqs}
    )

    return slides

# %%
product_categories = get_unique_product_groups(jira_roadmap_issues)
slides = generate_roadmap_slides(
    slides_service=slides_service, 
    presentation_id='1XDRX_Bq39GTT8_6r2oorklhkw-MuIpn-VqFUSHn_Fdo', 
    product_categories=product_categories,
    roadmap_slide_config=roadmap_slide_config
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 6
#       1 product_categories = get_unique_product_groups(jira_roadmap_issues)
#       2 slides = generate_roadmap_slides(
#       3     slides_service=slides_service,
#       4     presentation_id='1XDRX_Bq39GTT8_6r2oorklhkw-MuIpn-VqFUSHn_Fdo',
#       5     product_categories=product_categories,
# ----> 6     roadmap_slide_config=roadmap_slide_config
#       7 )
#
# NameError: name 'roadmap_slide_config' is not defined

# %% [markdown]
# ### Iterate through Jira Issues to create shapes

# %%
def populate_roadmap_with_issues(
    presentation_id, 
    slides_service, 
    roadmap_slides, 
    curr_quarter, 
    roadmap_slide_config
):
    '''Places the roadmap items on the slides provided based on the config

    Args:
        presentation_id (str): google id of presentation to add slides to
        slides_service (): google authenticated service to use when creating slides
        roadmap_slides (list(Slide)): slides for placing the roadmap items on
        curr_quarter (int): current quarter (1 - 4)
        roadmap_slide_config (dict): configuraiton for the roadmap slides

    Returns: 
        (list): updates made to the slides
    '''

    roadmap_box_config = roadmap_slide_config['roadmap_box']
    arrow_config = roadmap_slide_config['timeline_arrow']
    left_header_config = roadmap_slide_config['left_header']
    quarters_config = roadmap_slide_config['quarters']
    quarter_marker_config = roadmap_slide_config['quarter_marker']
    columns_config = roadmap_slide_config['columns']

    roadmap_box_width = (arrow_config['width'] - roadmap_box_config['x_padding'] * (quarters_config['num_quarter_groups'] + 1)) \
        / quarters_config['num_quarter_groups']
    roadmap_box_locx = left_header_config['locx'] + left_header_config['width'] + roadmap_box_config['x_padding']
    roadmap_box_locy = left_header_config['locy'] + left_header_config['height']
    
    roadmap_shapes = []

    for slide in roadmap_slides:

        for col in columns_config:
            col['count'] = 0
    
        for issue in jira_roadmap_issues:
    
            if slide.product_category in issue.product_categories:

                for col_num, col in enumerate(columns_config):
                    
                    if issue.jira_quarter in col['jira_statuses']:

                        locx = roadmap_box_locx + (roadmap_box_width + roadmap_box_config["x_padding"]) * col_num

                        locy = col['count'] * (roadmap_box_config["height"] + roadmap_box_config["y_padding"]) + roadmap_box_locy

                        col['count'] += 1

                        roadmap_shape, shape_id = gen_roadmap_item_req(
                            page_id=slide.google_slide_id,
                            tagline=issue.summary,
                            description=issue.description[:roadmap_box_config["description_length"]],
                            width=roadmap_box_width,
                            locx=locx,
                            locy=locy,
                            link=issue.jira_link,
                            roadmap_box_config=roadmap_box_config
                        )
                
                        roadmap_shapes.append(roadmap_shape)
    
    return updateSlides(
        service = slides_service,
        presentationId = presentation_id,
        body = {'requests': roadmap_shapes}
    )

# %% [markdown]
# ## Final structure

# %% [markdown]
# ### Config file

# %%
roadmap_slide_config = {
    "jira_roadmap_issues":{
        "jql_filter":'project = CDFNEW and issuetype = "Roadmap Initiative" and status in ("Q1", "Q2", "Q3", "Q4") ORDER BY Rank ASC',
        "product_category_mode": 'components',
        "product_category_prefix":'Product - '
    },
    "left_header": {
        "shape_type":'ROUND_RECTANGLE',
        "locx":35,
        "locy":100,
        "height":30,
        "width":170,
        "color":'ACCENT1',
        "font_size":12
    },
    "left_main":{
        "shape_type":'RECTANGLE',
        "locy":100,
        "height":280,
        "width":170,
        "color":'LIGHT2',
        "font_size":10,
        "text":"Describe the product category in a few sentences with 1 - 3 bulleted themes for the roadmap."}
    ,
    "timeline_arrow":{
        "color":'DARK1',
        "weight":2,
        "width":480
    },
    "quarter_marker":{
        "shape_type": "DIAMOND",
        "height":20, 
        "width":20, 
        "color":"ACCENT1",
        "font_size":14,
        "font":"Manrope",
        "font_color":"DARK1"
    },
    "roadmap_box": {
        "description_length":200,
        "height":50,
        "font_size":7,
        "font_color":"DARK1",
        "x_padding":5,
        "y_padding":5,
        "fill_color":"LIGHT1",
        "outline_color":"ACCENT1",
        "shape_type":"ROUND_RECTANGLE"
    },
    "quarters":{
        "quarter_jira_statuses":{
            1: "Q1",
            2: "Q2",
            3: "Q3",
            4: "Q4"
        },
        "num_quarter_groups": 3,
        "group_quarters": [3,4]
    },
    "columns": [
        {
            "jira_statuses":["Q2"],
            "label":"Q2 2024"
        },
        {
            "jira_statuses":["Q3"],
            "label":"Q3 2024"
        },
        {
            "jira_statuses":["Q4","Q1"],
            "label":"Q4 2024 - Q1 2025"
        }
    ]
}

# %%
with open('config.json', 'w') as fp:
    json.dump(roadmap_slide_config, fp)

# %% [markdown]
# ### Authenticate

# %%
jira_roadmap_issues = get_roadmap_issues(
    jira_service=jira_client, 
    **roadmap_slide_config['jira_roadmap_issues']
)

product_categories = get_unique_product_groups(jira_roadmap_issues)

slides = generate_roadmap_slides(
    slides_service=google_client, 
    presentation_id=PRESENTATION_ID, 
    product_categories=product_categories,
    roadmap_slide_config=roadmap_slide_config
)

res_populate_roadmap = populate_roadmap_with_issues(
    presentation_id=PRESENTATION_ID,
    slides_service=google_client,
    roadmap_slides=slides, 
    roadmap_slide_config=roadmap_slide_config,
    jira_roadmap_issues=jira_roadmap_issues
)

# %%
def generate_roadmap_deck(jira_service, google_service, roadmap_slide_config, presentation_id):
    '''Get the jira roadmap issues and generate all of the slides with the details
    
    Args: 
        jira_service (JIRA): authenticated service used for interacting with jira
        google_service (): google authenticated service to use when creating slides
        roadmap_slide_config (dict): configuraiton for the roadmap slides 
        presentation_id (str): google id of presentation to add slides to
    '''

    jira_roadmap_issues = get_roadmap_issues(
        jira_service=jira_service, 
        **roadmap_slide_config['jira_roadmap_issues']
    )
    
    product_categories = get_unique_product_groups(jira_roadmap_issues)
    
    slides = generate_roadmap_slides(
        slides_service=google_service, 
        presentation_id=presentation_id, 
        product_categories=product_categories,
        roadmap_slide_config=roadmap_slide_config
    )
    
    res_populate_roadmap = populate_roadmap_with_issues(
        presentation_id=presentation_id,
        slides_service=google_service,
        roadmap_slides=slides, 
        roadmap_slide_config=roadmap_slide_config,
        jira_roadmap_issues=jira_roadmap_issues
    )

    return f"Generated {len(slides)*2} slides, {len(product_categories)} product categories, and {len(jira_roadmap_issues)} roadmap items."

# %% [markdown]
# # Final

# %%
from lib import google_slides_connect, JIRA, generate_roadmap_deck
from getpass import getpass
import json

with open('config.json', 'r') as f:
    roadmap_slide_config = json.load(f)

google_client = google_slides_connect()
jira_client = JIRA(basic_auth=("hunter.beck@cognite.com", getpass('Jira API Key:')), options={'server': 'https://cognitedata.atlassian.net/'})

PRESENTATION_ID = '1XDRX_Bq39GTT8_6r2oorklhkw-MuIpn-VqFUSHn_Fdo'
# Out:
# /Users/hunterbeck/Repos/jira-slide-generator/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=1076520620839-3cadpb9secdetc938k51obvoc2tl79sc.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpresentations&state=V4EuDnV9wTn0CZxYEktU20MOBz2vvK&access_type=offline
# Jira API Key: ········

# %%
with open('config.json', 'r') as f:
    roadmap_slide_config = json.load(f)

generate_roadmap_deck(jira_client, google_client, roadmap_slide_config, PRESENTATION_ID)
# Out:
# 'Generated 42 slides, 21 product categories, and 358 roadmap items.'

# %%
infield_items = get_roadmap_issues(
    jira_service=jira_cloud, 
    jql_filter='project = CDFNEW and issuetype = "Roadmap Initiative" and status in ("Q1", "Q2", "Q3", "Q4") ORDER BY Rank ASC',
    product_category_mode = 'components',
    product_category_prefix='Product - InField'
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 infield_items = get_roadmap_issues(
#       2     jira_service=jira_cloud,
#       3     jql_filter='project = CDFNEW and issuetype = "Roadmap Initiative" and status in ("Q1", "Q2", "Q3", "Q4") ORDER BY Rank ASC',
#       4     product_category_mode = 'components',
#       5     product_category_prefix='Product - InField'
#       6 )
#
# NameError: name 'get_roadmap_issues' is not defined

# %%
[item.description[:200] for item in infield_items]
# Out:
# ['Set up alerts and notifications that trigger when thresholds or anomalies are detected for critical equipment and processes.',
#  'Laying the grounds for a cohesive experience through the Cognite Data Fusion portfolio targeted towards workflows and user groups within designated workspaces. Supporting the quick start package, with',
#  '*Single Sign-on*\xa0\n\nStandardized log-in across all Cognite products, enabled by Cognite IdP integrating with customer IdP',
#  'In product help center - guided experience to complete a set of tutorials to become a novice user',
#  'Improve the Asset Health offering by leveraging gen AI on data analysis while working in a collaborative canvas.\nCo-pilot in Industrial Canvas. \nContinuously adding AI features into canvas. \n\n[https:/',
#  'Low-code client built applications in Python using Streamlit from Fusion',
#  'Support for over 100 source system\xa0 relevant for Heavy asset Industry',
#  'Extractor for the industrial process historian Aspentech InfoPlus. 21',
#  'As a CDF user I want to ingest my engineering diagrams with high quality and being able to contextualize them',
#  'Bring our hosted extractor (MQTT, Rest API & Kafka) to a productized level. ',
#  'Simpler user experience by using CDF data models',
#  'Extend “Ask question” functionality to enable questioning across all documents assosciated with an equipment.',
#  'API for doing “document questioning”, e.g. asking questions such as “How do I prepare this equipment for transportation?” allowing client/partner developers to build data insight apps on top of CDF. \n',
#  'AI-based smart isolation boundaries and smart work suggestion on P&IDs',
#  'Contextualization of key value pairs from datasheets with human-in-the-loop validation. Planned for Public Beta in April.\n\nNote: Fusion UI. API not for external exposure.',
#  'A set of GenAI API capabilities to solve concrete use cases, such as “document interrogation”, “natural language data insights” and “time series analytics”. A service that understands industrial data ',
#  'Comment, tag, and notify other users / functions from the field. \n\nE.g. “Work preperation” with link to Collaborative Planning/Asset Health',
#  'Utilise Search/FDX/Resource component as the “data explorer” in InField and InRobot. Focus on desktop experience. ',
#  'Observations” (e.g. from inspection rounds) have spatial location and can be explored in 3D',
#  'Group data by site/area, and data model independent search for all DM data I have access to',
#  'Support for large scale, medium complexity data as dedicated storage / resource type',
#  '360 images segmented using AI models. Human-in-the-loop to contextualize these',
#  'Find, use and build from templated and managed Data Models / Types',
#  'New out-of-the-box data models\n\n[https://cognitedata.atlassian.net/wiki/spaces/PD/pages/4002447652/WIP+Manufacturing+Process+Data+Model+-+Product+Requirement+Document|https://cognitedata.atlassian.net',
#  'Upgrade existing asset hierarchy data and resource metadata\xa0 to Data Modeling',
#  'Making it more efficient to iterate on and update/upgrade existing data models.',
#  'Cognite Data Fusion running with identical feature set and SLAs across all 3 cloud platforms',
#  'Integrate to PETEX GAP simulator as a Process Twin to build performance monitoring and production optimization workflows.',
#  'Integrate to SLB PIPESIM simulator as a Process Twin to build performance monitoring and production optimization workflows.',
#  'Use the connector developer toolkit with instructions, library and open source examples to enable vendors and partners.',
#  'Support for more advanced steps in the simulation routines, enabling users to run complex simulation workflows.',
#  'Support for creating simulation workflows using Cognite APIs, enabling users to scale simulations to thousands of models.',
#  'Use data from data models as simulation inputs and save results directly to data models.',
#  'Speed up the process of connecting process data to simulation models using an AI guided contextualization engine.',
#  'Allow users to extend Cognite’s unit catalog with custom units.',
#  'Integrate to AspenTech AspenPlus simulator as a Process Twin to build performance monitoring and production optimization workflows.',
#  'Choose to make checklists with only your tasks/operations and modify the checklist before executing in the field\xa0',
#  'Efficiently leverage standardized equipment checklists in the field',
#  'Ability to create dependencies between work orders and automatically sequence them',
#  'Identify\xa0 potential gaps & opportunities down to hour level between the activities that need to be done vs the available resources',
#  'Persistence of Charts no-code calculation results in Cognite Data Fusion.',
#  'Evaluate site and equipment performance by assessing out of the box performance overviews with predefined metrics.',
#  'Improve the Asset Health offering by leveraging gen AI while doing data analysis, working in a canvas, identifying risks or creating monitoring.',
#  'Create repeatable templates to common problems\xa0 such as troubleshooting a failed well, heat exchanger analysis etc.',
#  'Representation of Time Series as a native system type in Data Models. This will allow CDF users, (via Data Exploration, Search and Filtering) to reason about a given Time Series in FDM (what the Time ',
#  'Understand the budget impact of scoping decisions while optimising campaign and turnaround work scopes',
#  'Track live progress of execution based on updates in the CMMS',
#  'Easily discover historic work orders, notifications and respective\xa0 attachments',
#  'Ability to\xa0 collaborate in canvases across Cognite surfaces to prepare work in context. Create new canvases from maintain and bring them back in context of your plan',
#  'Unified landing page for CDF Business user with InField sub-apps.',
#  'Collaborate better across functions on backlog prioritisation, preparation or plan optimisation through chatting and tagging colleagues ',
#  'General Availability - production grade for Monitoring in Charts and Industrial Canvas.',
#  'Gain insights by working with several data types in a canvas. Identify corrosions and vibrations by using\xa0 conditional formatting.\n\n[https://cognitedata.atlassian.net/wiki/spaces/PD/pages/4281597953|h',
#  'Assessing and benchmarking current equipment performance against production constraints to refine operational strategies',
#  'Identify and assess critical equipment, configure rules and create effective actions. Risk overviews that highlight criticalities.',
#  'Identify recurrent issues and 10X the speed of RCAs by effective data collection, powerful tools and RCA templates.',
#  'Customizable and personalized overviews of equipments and site performance\xa0 based on user roles and business priorities/targets.',
#  'This initiative will: \n\n* Provide the means to allocate an entity in a Data Model to a Time Zone.\n* Provide the means to retrieve data points from a Time Series using time ranges from any Time Zone (b',
#  'In order for CDF to be simple to use and relevant for use in the generation of business focused reports, it is required to have the ability to generate reports based on calendar based epochs, such as ',
#  '*Simplified user & access management*\n\nCDF admins can manage user groups and access rights in CDF, using predefined or custom roles',
#  'Develop a streamlined workflow based on the scene, simplifying the contextualization tasks for point clouds, 360 images, CAD models.',
#  'As a user you will be able to have an unified experienced given your file is structured or unstructured. You will be able to extract relevant information and integrate it with other other CDF workflow',
#  'Uniting spatial and non-spatial data, enabling users to mark and note discoveries directly in the 3D space, thereby enhancing spatial awareness of the discovery. This concept, will be added into our 3',
#  'Point clouds, 360 images and 2D drawings(?) segmented using AI models to accelerate the contextualization workflow.',
#  'Fetch video recordings from observations to generate a high fidelity 3D model based on the content of the clip. Position it correctly in geo-space, and potentially inherit contextualization from asset',
#  'Provide suggested entity matching from 3D node names and asset hierarchy / equipment tags upon CAD file ingestion.',
#  'Enabling a guided workflow for creation of scenes, contextualization of 3D data, and management of the 3D environment.',
#  'There a need to provide better monitoring, metrics and alerting to the data coming to CDF. This should be aligned with how we deal with Data Pipelines in general in CDF. ',
#  'Enable a continuous evolution and persistence of contextualization, threshold monitoring, and scene configurations across model revisions. By seamlessly managing revisions, users maintain a consistent',
#  'Extend Documents API with “semantic search”/”similarity search” that allows searching for content in documents by semantic meaning rather than keywords (e.g. “Personell injury” is semantically similar',
#  'Ability to discover Charts and Canvases from Search and the Flexible Resource Selector. Users shall be able to list available Charts and Canvases, be able to search for Charts/Canvases and on individu',
#  '*Project defined UI customization (not for end user to adjust)*\n\nIn the project wide configuration, the Admin/SA/DE should be able to define how data is presented. Details in PRD: [https://cognitedata',
#  'Ties to our goal of unification across the portfolio, and enablement of the MAIA initiative; a quick start package fully on DM.  Unifying the experience for finding and adding data across the portfoli',
#  'Organize and orchestrate data pipelines consisting of Transformations, Functions and CDF requests.\n\n[https://cognitedata.atlassian.net/wiki/x/GwAuAwE|https://cognitedata.atlassian.net/wiki/x/GwAuAwE|s',
#  'Build and understand data workflows in CDF through a unified user interface.\n\n[https://cognitedata.atlassian.net/wiki/spaces/PD/pages/4079550471/PRD+Fusion+sub-app+for+Workflow+Orchestration|https://c',
#  'Comprehensive overview of the operational status of data onboarding in a unified interface.',
#  'Execute data workflows based on changes in state or updates to data.',
#  'Simulation data model is extracted and visualized, enabling a more native exploration of the Process Twin.',
#  'Speed up the process of assigning the correct units to data by using an AI guided contextualization engine.',
#  'Expose the new unit information in Cognite User Interfaces',
#  'Ability for the user to set flags in Charts at various time stamps and annotate them',
#  'Revamp of overview page in charts to match industrial canvas and create a seamless experience between the two capabilities in CDF',
#  ' Simulate threshold models on historical data to build trust in future alerts and monitoring jobs',
#  'Ability to setup multiple thresholds on a given time series in charts',
#  'Addition of a new in between ( <> ) threshold model for easy monitoring and alerting use',
#  'Ability to scale charts visualisation, calculations and monitoring jobs through templatised charts',
#  'Monitoring and alerting capabilities in charts FE will be in GA production.',
#  'Ability to query and consume alerts generated in charts in other external contexts such as grafana',
#  'Ability to create monitoring jobs using the API instead of the front end for scaled use cases and speed of creation',
#  'Improve on charts search functionalities to expand on use cases and enhance user experience',
#  'Better indicators of data quality issues such as missing data and gaps in charts.',
#  'Improvements in the time series plotting capability to enhance user experience and performance',
#  'Unit improvements in Charts to enhance usability and user experience',
#  'Ability to set and visualize the user set decimal and significant digit values for industrial data in Charts',
#  'Ability to comment and tag people in Charts.',
#  'Improvements in the events functionalities in Charts to make them easier to setup and provide value quickly',
#  'Ability to visualize alerts on a given time series in a Chart',
#  'Improve on node editor and provide an easier way to create simple calculations',
#  'A “human friendly” approach to focus the search for data relevant to my job.',
#  'Search and add data in Canvas and Charts. Work with data across all data models from FDM and Asset Centric. \n[https://cognitedata.atlassian.net/wiki/spaces/PD/pages/4176678137|https://cognitedata.atla',
#  '*Isolation markups/boundaries*\xa0Marking out the isolation boundaries on P&IDs. Visually marking the areas where energy sources need to be isolated\n[https://cognitedata.atlassian.net/wiki/spaces/PD/page',
#  '\n\nUsers\xa0 can generate service accounts, fully managed in CDF - without the need to contact local IT admin',
#  '\n\n3rd party developers can use Cognite IdP for authorization and\xa0 SSO',
#  'Nested Data Sets and improved governance mechanisms enables more granular access control',
#  'Users can generate automated data lineage overviews allowing for fast troubleshooting and increased trust amongst data consumers',
#  'Users can access automatically generated data quality metrics for their Data Models, reducing need for manual inspection and setting up external processes',
#  'Ability for customers to consume audit logs as a service',
#  'After searching/filtering data in Cognite Search, allow asking “data insights” questions, e.g. after scoping down work orders to work performed last week, ask questions such as “What was the mean dura',
#  '“Interrogate” data added to a canvas across multiple data types. Examples might be questions on operating limitations for equipment where information can be found both in documents and in equipment de',
#  'Integrate common streaming technologies as data sources to CDF (Rest API and Kafka)\n\nRest API support will be Beta for the API, however capabilities in the UI will be minimal (Alpha)',
#  'Ability to write back in SAP PM (Plant Maintenance) notifications from InField. \n\nThis feature will provide a scalable product supporting multi cloud  (AWS, Azure & Google)',
#  'Being able to contextualized vectorized P&IDs to identify valves and connection through them. This initiative will enable workflows such as semi automatic Isolation Planning in Maintain. \n\nBy the time',
#  'Empower industrial end users with the capability to effortlessly calculate volume, area, and multiple points measurements directly within their 3D environment, streamlining decision-making processes a',
#  'Elevate slicing capabilities in the x, y, and z directions, through sectioning and slicing plane tools. This advancement enables users to precisely isolate and analyze sections of the 3D model, foster',
#  'This initiative will implement support for the representation of Machine States in Time Series.\n\nFor example, where a machine has states ON, OFF or STANDBY, in Time Series today, these states are repr',
#  'This initiative will implement support for the ingestion, storage and retrieval of a custom type where vibration (or other high resolution type) data is stored in CDF.\n\n',
#  'Ability to discover Checklists created by the Field worker, Turn Around Plans by the Maintenance engineer etc. from Search and the Flexible Resource Selector. Requires InField and Maintain to make the',
#  '“Observation”, “Media”, “Checklists” as re-suable componentized views. Allowing these data types to easily be surfaced in Canvas, Fusion, etc. and make sense for the users to trigger troubleshooting, ',
#  'Plan & create robotic missions using the digital twin and 360 images, no need to send out the robot during this phase\xa0',
#  'Configure Observations to fit your field workflows, ensuring that data is captured in an actionable way for your operations. \n\nAlso including a SAP Notifications write-back from Observations (comes wi',
#  ' Automate data pipeline execution using schedules.\n\n[https://cognitedata.atlassian.net/wiki/x/GwAuAwE|https://cognitedata.atlassian.net/wiki/x/GwAuAwE|smart-link] ',
#  'Including re-runs, improved robustness, nested workflow triggering, and CLI-based management and deployment.\n\n[https://cognitedata.atlassian.net/wiki/x/GwAuAwE|https://cognitedata.atlassian.net/wiki/x',
#  'Populate all essential parts of Data Models using Transformations.\n\n[https://cognitedata.atlassian.net/wiki/spaces/PD/pages/4242507579/PRD+-+Support+Core+Data+Model+and+Units+in+Transformations|https:',
#  'Extend “Ask question” functionality to enable interrogation across all documents added to a canvas and/or multiple documents in a search result.',
#  'Leverage GenAI to parse old checklists and generate structured versions',
#  'Point clouds segmented using AI models. Human-in-the-loop to contextualize these',
#  'Extension of the monitoring concept in 3D adding time series as a trigger for color change.',
#  'Bringing all the capabilities of InField and Maintain into [fusion.cognite.com|http://fusion.cognite.com], providing seamless navigation between any InField and/or Maintain capability and Canvas and C',
#  'Leveraging WebGPU to boost performance and expand technical capabilities in our 3D viewer. Anticipate smoother CAD model visualization, reduced lag, and improved rendering quality. Success measured by',
#  'Making known information into “suggesters” for contextualization of 3D, making the process more efficient, increasing the amount of contextualized objects and improving the overall experience of using',
#  'Enabling users to manipulate objects and/or models, by either hiding, ghosting or adjusting opacity, the overall clarity and comprehension of the 3D scene can be enhanced significantly. This improved ',
#  'As InField, Maintain and Search will co-exist in the same workspace we need to ensure that the overall 3D experience is unified, and that the entry points do not lead to breaking changes for the end u',
#  'Launch a dedicated Help Center within our CDF platform, offering users resources, and support documentation. This initiative aims to empower users with readily accessible guidance, enhancing their und',
#  'Introduce a collections feature to give users a unified view of equipment, production processes, and diverse data resources. By organizing information into cohesive collections, users gain improved ov',
#  'Improve user preference settings and history tracking functionalities to enhance the user experience. Allowing users to set more custom preferences and improve the tracking of their history, we aim to',
#  'Introduce a global location selector across the product portfolio, empowering users to filter data by location for a more targeted experience. This initiative aims to improve the data accessibility by',
#  'Support seamless way of building a cause map in IC [https://cognitedata.atlassian.net/wiki/spaces/PD/pages/4276256770|https://cognitedata.atlassian.net/wiki/spaces/PD/pages/4276256770|smart-link] ',
#  'The canvas is linked to equipment, work orders etc. Easy to find RCA analysis based on search and tagging system.\n[https://cognitedata.atlassian.net/wiki/spaces/PD/pages/4169367553|https://cognitedata',
#  '*Storyline and navigation*\xa0\n\nEasily navigate through a canvas (sections, mini map navigation).\xa0Search within a canvas content is enabled.',
#  '*Access Management\xa0-* A canvas can be private, public or shared with specific users. Edit/view mode.',
#  'Real time collaboration across users from multiple disciplines. Multiple users can edit at the same time a canvas.',
#  'Creating suggestions automatically for\xa0 isolations boundaries. Overlaying work orders and more data types on top of diagrams.',
#  'Canvas as a shareable component that can be used in other custom apps at our customers.',
#  'Read-only version of Maintain for quick deployment.\n\nKey workflows \n\n# *Workorder Readiness Assessment:* Evaluate the readiness of workorders.\n# *Workorder Opportunities Discovery:* Identify potential',
#  '*Create functionality to define per project file classification based on rules, and use this to present files per class in UIs.* \n\nWe need to provide users with a classification of Files. In Data Expl',
#  'In their personal configuration of Search, the user should be able to define the following through the Search FE (and it applies to the resource selector where that is used across the portfolio); Whic',
#  'A system data model for defining global filter that will be used for filtering on “Location”. In the new Data Insight workspace in Fusion to be released in Q2, we will in Q3 include a Location filter ',
#  'The Cognite data model/the core data model and defined Industrial Data Model extensions will have a set of core types that we have defined in Cognite and know what represents. Thus, we also can be opi',
#  'The Cognite data model/the core data model and defined Industrial Data Model extensions will have a set of core types that we have defined in Cognite and know what represents. Thus, we also can be opi',
#  'Provide an OPC UA interface that allows software applications that use the OPC UA protocol to perform operations on OPC UA data as stored in CDF.',
#  'Audit logs will be streamed to customer provided storage bucket / blog storage. \n\n*Audit logs from CDF (Q4 2024) will contain:* \n\nAuthentication details \n- Information from customer IdP \n- Reconciled ',
#  'Convert source system units to units in CDF using Transformations. \n\n[https://cognitedata.atlassian.net/wiki/spaces/PD/pages/4242507579/PRD+-+Support+Core+Data+Model+and+Units+in+Transformations|https',
#  'General improvements to the SAP extractor such as: \n\n* Attachment ingestion\n* Splitting large data range inputs\n* Document extraction\n* Nested entity queries']

# %%
d = {1:'one',2:'two', 3:'three'}

# %%
list(d.keys())[-1]
# Out:
# 3

# %%
import datetime as datetime

# %%
datetime.datetime.now().year
# Out:
# 2024

# %%
roadmap_slide_config['columns']
# Out:
# [{'jira_statuses': ['Q2'], 'label': 'Q2 2024'},
#  {'jira_statuses': ['Q3'], 'label': 'Q3 2024'},
#  {'jira_statuses': ['Q4', 'Q1'], 'label': 'Q4 2024 - Q1 2025'}]

# %%
for col in roadmap_slide_config['columns']:
    col['count'] = 1
